# %%
with open('deu.txt', 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')
print("文档总共有 {} 行。".format(len(lines)))
num_samples = 20000 # 使用的语料行数
lines_to_use = lines[ : min(num_samples, len(lines)-1)]
print(lines_to_use)
# Out:
# 文档总共有 176693 行。
# ['Hi.\tHallo!', 'Hi.\tGrüß Gott!', 'Run!\tLauf!', 'Wow!\tPotzdonner!', 'Wow!\tDonnerwetter!', 'Fire!\tFeuer!', 'Help!\tHilfe!', 'Help!\tZu Hülf!', 'Stop!\tStopp!', 'Wait!\tWarte!', 'Go on.\tMach weiter.', 'Hello!\tHallo!', 'I ran.\tIch rannte.', 'I see.\tIch verstehe.', 'I see.\tAha.', 'I try.\tIch probiere es.', 'I won!\tIch hab gewonnen!', 'I won!\tIch habe gewonnen!', 'Smile.\tLächeln!', 'Cheers!\tZum Wohl!', 'Freeze!\tKeine Bewegung!', 'Freeze!\tStehenbleiben!', 'Got it?\tKapiert?', 'Got it?\tVerstanden?', 'Got it?\tEinverstanden?', 'He ran.\tEr rannte.', 'He ran.\tEr lief.', 'Hop in.\tMach mit!', 'Hug me.\tDrück mich!', 'Hug me.\tNimm mich in den Arm!', 'Hug me.\tUmarme mich!', 'I fell.\tIch fiel.', 'I fell.\tIch fiel hin.', 'I fell.\tIch stürzte.', 'I fell.\tIch bin hingefallen.', 'I fell.\tIch bin gestürzt.', 'I know.\tIch weiß.', 'I lied.\tIch habe gelogen.', 'I lost.\tIch habe verloren.', 'I paid.\tIch habe bezahlt.', 'I paid.\tIch zahlte.', 'I swim.\tIch schwimme.', "I'm 19.\tIch bin 19 Jahre alt.", "I'm 19.\tIch bin 19.", "I'm OK.\tMir geht's gut.", "I'm OK.\tEs geht mir gut.", "I'm up.\tIch bin wach.", "I'm up.\tIch bin auf.", 'No way!\tUnmöglich!', 'No way!\tDas kommt nicht in Frage!', 'No way!\tDas gibt’s doch nicht!', 'No way!\tAusgeschlossen!', 'No way!\tIn keinster Weise!', 'Really?\tWirklich?', 'Really?\tEcht?', 'Really?\tIm Ernst?', 'Thanks.\tDanke!', 'Try it.\tVersuch’s!', 'Why me?\tWarum ich?', 'Ask Tom.\tFrag Tom!', 'Ask Tom.\tFragen Sie Tom!', 'Ask Tom.\tFragt Tom!', 'Be cool.\tEntspann dich!', 'Be fair.\tSei nicht ungerecht!', 'Be fair.\tSei fair!', 'Be nice.\tSei nett!', 'Be nice.\tSeien Sie nett!', 'Beat it.\tGeh weg!', 'Beat it.\tHau ab!', 'Beat it.\tVerschwinde!', 'Beat it.\tVerdufte!', 'Beat it.\tMach dich fort!', 'Beat it.\tZieh Leine!', 'Beat it.\tMach dich vom Acker!', 'Beat it.\tVerzieh dich!', 'Beat it.\tVerkrümele dich!', 'Beat it.\tTroll dich!', 'Beat it.\tZisch ab!', 'Beat it.\tPack dich!', 'Beat it.\tMach ’ne Fliege!', 'Beat it.\tSchwirr ab!', 'Beat it.\tMach die Sause!', 'Beat it.\tScher dich weg!', 'Beat it.\tScher dich fort!', 'Call me.\tRuf mich an.', 'Come in.\tKomm herein.', 'Come in.\tHerein!', 'Come on!\tKomm!', 'Come on!\tKommt!', 'Come on!\tMach schon!', 'Come on!\tMacht schon!', 'Come on.\tKomm schon!', 'Get Tom.\tHol Tom.', 'Get out!\tRaus!', 'Get out.\tGeh raus.', 'Get out.\tGeht raus!', 'Go away!\tGeh weg!', 'Go away!\tHau ab!', 'Go away!\tVerschwinde!', 'Go away!\tVerdufte!', 'Go away!\tMach dich fort!', 'Go away!\tZieh Leine!', 'Go away!\tMach dich vom Acker!', 'Go away!\tVerzieh dich!', 'Go away!\tVerkrümele dich!', 'Go away!\tTroll dich!', 'Go away!\tZisch ab!', 'Go away!\tPack dich!', 'Go away!\tMach ’ne Fliege!', 'Go away!\tSchwirr ab!', 'Go away!\tMach die Sause!', 'Go away!\tScher dich weg!', 'Go away!\tScher dich fort!', 'Go away.\tGeh weg!', 'Go away.\tVerpiss dich!', 'Go away.\tHau ab!', 'Go away.\tVerschwinde!', 'Go away.\tVerdufte!', 'Go away.\tMach dich fort!', 'Go away.\tZieh Leine!', 'Go away.\tMach dich vom Acker!', 'Go away.\tVerzieh dich!', 'Go away.\tVerkrümele dich!', 'Go away.\tTroll dich!', 'Go away.\tZisch ab!', 'Go away.\tPack dich!', 'Go away.\tMach ’ne Fliege!', 'Go away.\tSchwirr ab!', 'Go away.\tMach die Sause!', 'Go away.\tScher dich weg!', 'Go away.\tScher dich fort!', 'Go home.\tGeh nach Hause.', 'Go home.\tGeh heim.', 'Goodbye!\tAuf Wiedersehen!', 'Goodbye!\tTschüss!', 'Hang on!\tNicht nachlassen!', 'He came.\tEr kam.', 'He runs.\tEr rennt.', 'He runs.\tEr läuft.', 'Help me.\tHilf mir.', 'Help us.\tHilf uns!', 'Help us.\tHelft uns!', 'Help us.\tHelfen Sie uns!', 'Hi, Tom.\tHallo, Tom!', 'Hit Tom.\tSchlage Tom!', 'Hit Tom.\tSchlagt Tom!', 'Hit Tom.\tSchlagen Sie Tom!', 'Hold on.\tWarten Sie kurz!', 'Hug Tom.\tUmarme Tom!', 'Hug Tom.\tUmarmen Sie Tom!', 'Hug Tom.\tUmarmt Tom!', 'Hug Tom.\tDrückt Tom!', 'Hug Tom.\tDrücken Sie Tom!', 'Hug Tom.\tDrück Tom!', 'I agree.\tIch bin einverstanden.', 'I cried.\tIch weinte.', 'I cried.\tIch habe geweint.', ...

# %%
import re
# print(lines_to_use[19516])
for i in range(len(lines_to_use)):
    lines_to_use[i] = re.sub('\d', ' _NUMBER_ ', lines_to_use[i])
    # 用 ' _NUMBER_ ' 替换 数字（\d）
# print(lines_to_use[19516])
input_texts = []
target_texts = []
input_words = set()
target_words = set()
for line in lines_to_use:
    x, y = line.split('\t')
    y = 'BEGIN_ ' + y + ' _END'
    input_texts.append(x)
    target_texts.append(y)
    for word in x.split():
        if word not in input_words:
            input_words.add(word)
    for word in y.split():
        if word not in target_words:
            target_words.add(word)

# %%
max_input_seq_len = max([len(seq.split()) for seq in input_texts])
# 11
max_target_seq_len = max([len(seq.split()) for seq in target_texts])
# 15

input_words = sorted(list(input_words))
target_words = sorted(list(target_words))
num_encoder_tokens = len(input_words) # 5724
num_decoder_tokens = len(target_words) # 9126

# %%
inputToken_idx = {token : i for (i, token) in enumerate(input_words)}
outputToken_idx = {token : i for (i, token) in enumerate(target_words)}
idx_inputToken = {i : token for (i, token) in enumerate(input_words)}
idx_outputToken = {i : token for (i, token) in enumerate(target_words)}

# %%
import numpy as np
encoder_input_data = np.zeros(
    (len(input_texts), max_input_seq_len),
    # 句子数量，         最大输入句子长度
    dtype=np.float32
)

decoder_input_data = np.zeros(
    (len(target_texts), max_target_seq_len),
    # 句子数量，          最大输出句子长度
    dtype=np.float32
)

decoder_output_data = np.zeros(
    (len(target_texts), max_target_seq_len, num_decoder_tokens),
    # 句子数量，          最大输出句子长度,      输出 tokens ids 个数
    dtype=np.float32
)

# %%
for i,(input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, word in enumerate(input_text.split()):
        encoder_input_data[i, t] = inputToken_idx[word]
    for t, word in enumerate(target_text.split()):
        decoder_input_data[i, t] = outputToken_idx[word]
        if t > 0:
            # 解码器的输出比输入提前一个时间步
            decoder_output_data[i, t-1, outputToken_idx[word]] = 1.

# %%
from keras.layers import Input, LSTM, Embedding, Dense
from keras.models import Model

embedding_size = 256 # 嵌入维度
rnn_size = 64
# 编码器
encoder_inputs = Input(shape=(None,))
encoder_after_embedding = Embedding(input_dim=num_encoder_tokens, # 单词个数
                                    output_dim=embedding_size)(encoder_inputs)
encoder_lstm = LSTM(units=rnn_size, return_state=True)
# return_state: Boolean. Whether to return
#   the last state in addition to the output.
_, state_h, state_c = encoder_lstm(encoder_after_embedding)
encoder_states = [state_h, state_c]

# 解码器
decoder_inputs = Input(shape=(None,))
decoder_after_embedding = Embedding(input_dim=num_decoder_tokens, # 单词个数
                                    output_dim=embedding_size)(decoder_inputs)
decoder_lstm = LSTM(units=rnn_size, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_after_embedding,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_19"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, None, 256)    1465344     input_11[0][0]
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, None, 256)    2336256     input_12[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   [(None, 64), (None,  82176       embedding_4[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   [(None, None, 64), ( 82176       embedding_5[0][0]
#                                                                  lstm_4[0][1]
#                                                                  lstm_4[0][2]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, None, 9126)   593190      lstm_5[0][0]
# ==================================================================================================
# Total params: 4,559,142
# Trainable params: 4,559,142
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
 
filepath='weights.best.hdf5'
    # 有一次提升, 则覆盖一次.
checkpoint = ModelCheckpoint(filepath, monitor='accuracy', verbose=1,save_best_only=True,mode='max',save_freq=2) 
callbacks_list = [checkpoint]
# https://keras.io/api/callbacks/model_checkpoint/


history = model.fit(x=[encoder_input_data, decoder_input_data],y=decoder_output_data,
                    batch_size=128,epochs=200,validation_split=0.1,
                   callbacks=callbacks_list)
model.save('model.h5')
# Out:
# Epoch 1/200
#   1/141 [..............................] - ETA: 0s - loss: 2.7928 - accuracy: 0.0000e+00
# Epoch 00001: accuracy improved from -inf to 0.00000, saving model to weights.best.hdf5
#   3/141 [..............................] - ETA: 1:03 - loss: 2.7889 - accuracy: 0.0148
# Epoch 00001: accuracy improved from 0.00000 to 0.02760, saving model to weights.best.hdf5
#   5/141 [>.............................] - ETA: 1:17 - loss: 2.7854 - accuracy: 0.0354
# Epoch 00001: accuracy improved from 0.02760 to 0.04062, saving model to weights.best.hdf5
#   7/141 [>.............................] - ETA: 1:22 - loss: 2.8206 - accuracy: 0.0443
# Epoch 00001: accuracy improved from 0.04062 to 0.04714, saving model to weights.best.hdf5
#   9/141 [>.............................] - ETA: 1:24 - loss: 2.8281 - accuracy: 0.0493
# Epoch 00001: accuracy improved from 0.04714 to 0.05104, saving model to weights.best.hdf5
#  11/141 [=>............................] - ETA: 1:25 - loss: 2.8365 - accuracy: 0.0525
# Epoch 00001: accuracy improved from 0.05104 to 0.05365, saving model to weights.best.hdf5
#  13/141 [=>............................] - ETA: 1:25 - loss: 2.8370 - accuracy: 0.0546
# Epoch 00001: accuracy improved from 0.05365 to 0.05551, saving model to weights.best.hdf5
#  15/141 [==>...........................] - ETA: 1:24 - loss: 2.8329 - accuracy: 0.0562
# Epoch 00001: accuracy improved from 0.05551 to 0.05690, saving model to weights.best.hdf5
#  17/141 [==>...........................] - ETA: 1:23 - loss: 2.8295 - accuracy: 0.0575
# Epoch 00001: accuracy improved from 0.05690 to 0.05799, saving model to weights.best.hdf5
#  19/141 [===>..........................] - ETA: 1:24 - loss: 2.8143 - accuracy: 0.0584
# Epoch 00001: accuracy improved from 0.05799 to 0.05885, saving model to weights.best.hdf5
#  21/141 [===>..........................] - ETA: 1:23 - loss: 2.8071 - accuracy: 0.0592
# Epoch 00001: accuracy improved from 0.05885 to 0.05956, saving model to weights.best.hdf5
#  23/141 [===>..........................] - ETA: 1:22 - loss: 2.7949 - accuracy: 0.0599
# Epoch 00001: accuracy improved from 0.05956 to 0.06016, saving model to weights.best.hdf5
#  25/141 [====>.........................] - ETA: 1:22 - loss: 2.7784 - accuracy: 0.0604
# Epoch 00001: accuracy improved from 0.06016 to 0.06066, saving model to weights.best.hdf5
#  27/141 [====>.........................] - ETA: 1:20 - loss: 2.7582 - accuracy: 0.0609
# Epoch 00001: accuracy improved from 0.06066 to 0.06109, saving model to weights.best.hdf5
#  29/141 [=====>........................] - ETA: 1:19 - loss: 2.7358 - accuracy: 0.0613
# Epoch 00001: accuracy improved from 0.06109 to 0.06146, saving model to weights.best.hdf5
#  31/141 [=====>........................] - ETA: 1:19 - loss: 2.7139 - accuracy: 0.0616
# Epoch 00001: accuracy improved from 0.06146 to 0.06178, saving model to weights.best.hdf5
#  33/141 [======>.......................] - ETA: 1:18 - loss: 2.6934 - accuracy: 0.0619
# Epoch 00001: accuracy improved from 0.06178 to 0.06207, saving model to weights.best.hdf5
#  35/141 [======>.......................] - ETA: 1:16 - loss: 2.6708 - accuracy: 0.0622
# Epoch 00001: accuracy improved from 0.06207 to 0.06233, saving model to weights.best.hdf5
#  37/141 [======>.......................] - ETA: 1:15 - loss: 2.6488 - accuracy: 0.0624
# Epoch 00001: accuracy improved from 0.06233 to 0.06255, saving model to weights.best.hdf5
#  39/141 [=======>......................] - ETA: 1:13 - loss: 2.6254 - accuracy: 0.0627
# Epoch 00001: accuracy improved from 0.06255 to 0.06276, saving model to weights.best.hdf5
#  41/141 [=======>......................] - ETA: 1:12 - loss: 2.6026 - accuracy: 0.0629
# Epoch 00001: accuracy improved from 0.06276 to 0.06295, saving model to weights.best.hdf5
#  43/141 [========>.....................] - ETA: 1:10 - loss: 2.5812 - accuracy: 0.0630
# Epoch 00001: accuracy improved from 0.06295 to 0.06312, saving model to weights.best.hdf5
#  45/141 [========>.....................] - ETA: 1:09 - loss: 2.5598 - accuracy: 0.0632
# Epoch 00001: accuracy improved from 0.06312 to 0.06327, saving model to weights.best.hdf5
#  47/141 [=========>....................] - ETA: 1:07 - loss: 2.5367 - accuracy: 0.0633
# Epoch 00001: accuracy improved from 0.06327 to 0.06341, saving model to weights.best.hdf5
#  49/141 [=========>....................] - ETA: 1:06 - loss: 2.5150 - accuracy: 0.0635
# Epoch 00001: accuracy improved from 0.06341 to 0.06354, saving model to weights.best.hdf5
#  51/141 [=========>....................] - ETA: 1:04 - loss: 2.4940 - accuracy: 0.0636
# Epoch 00001: accuracy improved from 0.06354 to 0.06366, saving model to weights.best.hdf5
#  53/141 [==========>...................] - ETA: 1:03 - loss: 2.4748 - accuracy: 0.0637
# Epoch 00001: accuracy improved from 0.06366 to 0.06377, saving model to weights.best.hdf5
#  55/141 [==========>...................] - ETA: 1:02 - loss: 2.4576 - accuracy: 0.0638
# Epoch 00001: accuracy improved from 0.06377 to 0.06388, saving model to weights.best.hdf5
#  57/141 [===========>..................] - ETA: 1:00 - loss: 2.4376 - accuracy: 0.0639
# Epoch 00001: accuracy improved from 0.06388 to 0.06397, saving model to weights.best.hdf5
#  59/141 [===========>..................] - ETA: 59s - loss: 2.4184 - accuracy: 0.0640
# Epoch 00001: accuracy improved from 0.06397 to 0.06406, saving model to weights.best.hdf5
#  61/141 [===========>..................] - ETA: 57s - loss: 2.4015 - accuracy: 0.0641
# Epoch 00001: accuracy improved from 0.06406 to 0.06415, saving model to weights.best.hdf5
#  63/141 [============>.................] - ETA: 56s - loss: 2.3849 - accuracy: 0.0642
# Epoch 00001: accuracy improved from 0.06415 to 0.06423, saving model to weights.best.hdf5
#  65/141 [============>.................] - ETA: 55s - loss: 2.3690 - accuracy: 0.0643
# Epoch 00001: accuracy improved from 0.06423 to 0.06430, saving model to weights.best.hdf5
#  67/141 [=============>................] - ETA: 53s - loss: 2.3524 - accuracy: 0.0643
# Epoch 00001: accuracy improved from 0.06430 to 0.06437, saving model to weights.best.hdf5
#  69/141 [=============>................] - ETA: 52s - loss: 2.3365 - accuracy: 0.0644
# Epoch 00001: accuracy improved from 0.06437 to 0.06443, saving model to weights.best.hdf5
#  71/141 [==============>...............] - ETA: 50s - loss: 2.3232 - accuracy: 0.0645
# Epoch 00001: accuracy improved from 0.06443 to 0.06450, saving model to weights.best.hdf5
#  73/141 [==============>...............] - ETA: 49s - loss: 2.3111 - accuracy: 0.0645
# Epoch 00001: accuracy improved from 0.06450 to 0.06456, saving model to weights.best.hdf5
#  75/141 [==============>...............] - ETA: 48s - loss: 2.2972 - accuracy: 0.0646
# Epoch 00001: accuracy improved from 0.06456 to 0.06461, saving model to weights.best.hdf5
#  77/141 [===============>..............] - ETA: 46s - loss: 2.2851 - accuracy: 0.0646
# Epoch 00001: accuracy improved from 0.06461 to 0.06466, saving model to weights.best.hdf5
#  79/141 [===============>..............] - ETA: 45s - loss: 2.2737 - accuracy: 0.0647
# Epoch 00001: accuracy improved from 0.06466 to 0.06471, saving model to weights.best.hdf5
#  81/141 [================>.............] - ETA: 43s - loss: 2.2626 - accuracy: 0.0647
# Epoch 00001: accuracy improved from 0.06471 to 0.06476, saving model to weights.best.hdf5
#  83/141 [================>.............] - ETA: 42s - loss: 2.2525 - accuracy: 0.0648
# Epoch 00001: accuracy improved from 0.06476 to 0.06481, saving model to weights.best.hdf5
#  85/141 [=================>............] - ETA: 40s - loss: 2.2418 - accuracy: 0.0648
# Epoch 00001: accuracy improved from 0.06481 to 0.06485, saving model to weights.best.hdf5
#  87/141 [=================>............] - ETA: 39s - loss: 2.2326 - accuracy: 0.0649
# Epoch 00001: accuracy improved from 0.06485 to 0.06489, saving model to weights.best.hdf5
#  89/141 [=================>............] - ETA: 38s - loss: 2.2230 - accuracy: 0.0649
# Epoch 00001: accuracy improved from 0.06489 to 0.06493, saving model to weights.best.hdf5
#  91/141 [==================>...........] - ETA: 36s - loss: 2.2137 - accuracy: 0.0649
# Epoch 00001: accuracy improved from 0.06493 to 0.06497, saving model to weights.best.hdf5
#  93/141 [==================>...........] - ETA: 35s - loss: 2.2044 - accuracy: 0.0650
# Epoch 00001: accuracy improved from 0.06497 to 0.06500, saving model to weights.best.hdf5
#  95/141 [===================>..........] - ETA: 33s - loss: 2.1963 - accuracy: 0.0650
# Epoch 00001: accuracy improved from 0.06500 to 0.06504, saving model to weights.best.hdf5
#  97/141 [===================>..........] - ETA: 32s - loss: 2.1884 - accuracy: 0.0651
# Epoch 00001: accuracy improved from 0.06504 to 0.06507, saving model to weights.best.hdf5
#  99/141 [====================>.........] - ETA: 31s - loss: 2.1810 - accuracy: 0.0651
# Epoch 00001: accuracy improved from 0.06507 to 0.06510, saving model to weights.best.hdf5
# 101/141 [====================>.........] - ETA: 29s - loss: 2.1733 - accuracy: 0.0651
# Epoch 00001: accuracy improved from 0.06510 to 0.06513, saving model to weights.best.hdf5
# 103/141 [====================>.........] - ETA: 28s - loss: 2.1655 - accuracy: 0.0651
# Epoch 00001: accuracy improved from 0.06513 to 0.06516, saving model to weights.best.hdf5
# 105/141 [=====================>........] - ETA: 26s - loss: 2.1593 - accuracy: 0.0652
# Epoch 00001: accuracy improved from 0.06516 to 0.06519, saving model to weights.best.hdf5
# 107/141 [=====================>........] - ETA: 25s - loss: 2.1525 - accuracy: 0.0652
# Epoch 00001: accuracy improved from 0.06519 to 0.06522, saving model to weights.best.hdf5
# 109/141 [======================>.......] - ETA: 23s - loss: 2.1462 - accuracy: 0.0652
# Epoch 00001: accuracy improved from 0.06522 to 0.06525, saving model to weights.best.hdf5
# 111/141 [======================>.......] - ETA: 22s - loss: 2.1395 - accuracy: 0.0653
# Epoch 00001: accuracy improved from 0.06525 to 0.06527, saving model to weights.best.hdf5
# 113/141 [=======================>......] - ETA: 20s - loss: 2.1338 - accuracy: 0.0653
# Epoch 00001: accuracy improved from 0.06527 to 0.06530, saving model to weights.best.hdf5
# 115/141 [=======================>......] - ETA: 19s - loss: 2.1282 - accuracy: 0.0653
# Epoch 00001: accuracy improved from 0.06530 to 0.06532, saving model to weights.best.hdf5
# 117/141 [=======================>......] - ETA: 17s - loss: 2.1227 - accuracy: 0.0653
# Epoch 00001: accuracy improved from 0.06532 to 0.06534, saving model to weights.best.hdf5
# 119/141 [========================>.....] - ETA: 16s - loss: 2.1166 - accuracy: 0.0654
# Epoch 00001: accuracy improved from 0.06534 to 0.06536, saving model to weights.best.hdf5
# 121/141 [========================>.....] - ETA: 15s - loss: 2.1107 - accuracy: 0.0654
# Epoch 00001: accuracy improved from 0.06536 to 0.06539, saving model to weights.best.hdf5
# 123/141 [=========================>....] - ETA: 13s - loss: 2.1053 - accuracy: 0.0654
# Epoch 00001: accuracy improved from 0.06539 to 0.06541, saving model to weights.best.hdf5
# 125/141 [=========================>....] - ETA: 12s - loss: 2.1006 - accuracy: 0.0654
# Epoch 00001: accuracy improved from 0.06541 to 0.06543, saving model to weights.best.hdf5
# 127/141 [==========================>...] - ETA: 10s - loss: 2.0948 - accuracy: 0.0654
# Epoch 00001: accuracy improved from 0.06543 to 0.06545, saving model to weights.best.hdf5
# 129/141 [==========================>...] - ETA: 9s - loss: 2.0907 - accuracy: 0.0655
# Epoch 00001: accuracy improved from 0.06545 to 0.06546, saving model to weights.best.hdf5
# 131/141 [==========================>...] - ETA: 7s - loss: 2.0860 - accuracy: 0.0655
# Epoch 00001: accuracy improved from 0.06546 to 0.06548, saving model to weights.best.hdf5
# 133/141 [===========================>..] - ETA: 6s - loss: 2.0810 - accuracy: 0.0655
# Epoch 00001: accuracy improved from 0.06548 to 0.06550, saving model to weights.best.hdf5
# 135/141 [===========================>..] - ETA: 4s - loss: 2.0767 - accuracy: 0.0655
# Epoch 00001: accuracy improved from 0.06550 to 0.06552, saving model to weights.best.hdf5
# 137/141 [============================>.] - ETA: 3s - loss: 2.0726 - accuracy: 0.0655
# Epoch 00001: accuracy improved from 0.06552 to 0.06553, saving model to weights.best.hdf5
# 139/141 [============================>.] - ETA: 1s - loss: 2.0677 - accuracy: 0.0655
# Epoch 00001: accuracy improved from 0.06553 to 0.06555, saving model to weights.best.hdf5
# 141/141 [==============================] - 110s 779ms/step - loss: 2.0654 - accuracy: 0.0656 - val_loss: 1.8701 - val_accuracy: 0.0667
# Epoch 2/200
#
# Epoch 00002: accuracy improved from 0.06555 to 0.06667, saving model to weights.best.hdf5
#   2/141 [..............................] - ETA: 49s - loss: 1.7084 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#   4/141 [..............................] - ETA: 1:11 - loss: 1.7462 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#   6/141 [>.............................] - ETA: 1:17 - loss: 1.7453 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#   8/141 [>.............................] - ETA: 1:21 - loss: 1.7338 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  10/141 [=>............................] - ETA: 1:23 - loss: 1.7219 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  12/141 [=>............................] - ETA: 1:23 - loss: 1.7259 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  14/141 [=>............................] - ETA: 1:23 - loss: 1.7252 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  16/141 [==>...........................] - ETA: 1:22 - loss: 1.7205 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  18/141 [==>...........................] - ETA: 1:21 - loss: 1.7245 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  20/141 [===>..........................] - ETA: 1:20 - loss: 1.7207 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  22/141 [===>..........................] - ETA: 1:20 - loss: 1.7164 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  24/141 [====>.........................] - ETA: 1:20 - loss: 1.7166 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  26/141 [====>.........................] - ETA: 1:19 - loss: 1.7205 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  28/141 [====>.........................] - ETA: 1:18 - loss: 1.7184 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  30/141 [=====>........................] - ETA: 1:16 - loss: 1.7161 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  32/141 [=====>........................] - ETA: 1:15 - loss: 1.7162 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  34/141 [======>.......................] - ETA: 1:13 - loss: 1.7149 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  36/141 [======>.......................] - ETA: 1:12 - loss: 1.7120 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  38/141 [=======>......................] - ETA: 1:11 - loss: 1.7105 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  40/141 [=======>......................] - ETA: 1:09 - loss: 1.7126 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  42/141 [=======>......................] - ETA: 1:08 - loss: 1.7100 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  44/141 [========>.....................] - ETA: 1:07 - loss: 1.7091 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  46/141 [========>.....................] - ETA: 1:06 - loss: 1.7072 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  48/141 [=========>....................] - ETA: 1:04 - loss: 1.7063 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  50/141 [=========>....................] - ETA: 1:03 - loss: 1.7061 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  52/141 [==========>...................] - ETA: 1:02 - loss: 1.7052 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  54/141 [==========>...................] - ETA: 1:00 - loss: 1.7043 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  56/141 [==========>...................] - ETA: 59s - loss: 1.7035 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  58/141 [===========>..................] - ETA: 57s - loss: 1.7016 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  60/141 [===========>..................] - ETA: 56s - loss: 1.7010 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  62/141 [============>.................] - ETA: 55s - loss: 1.7022 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  64/141 [============>.................] - ETA: 53s - loss: 1.7031 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  66/141 [=============>................] - ETA: 52s - loss: 1.7033 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  68/141 [=============>................] - ETA: 51s - loss: 1.7028 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  70/141 [=============>................] - ETA: 49s - loss: 1.7010 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  72/141 [==============>...............] - ETA: 48s - loss: 1.6992 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  74/141 [==============>...............] - ETA: 46s - loss: 1.6977 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  76/141 [===============>..............] - ETA: 45s - loss: 1.6960 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  78/141 [===============>..............] - ETA: 44s - loss: 1.6942 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  80/141 [================>.............] - ETA: 42s - loss: 1.6923 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  82/141 [================>.............] - ETA: 41s - loss: 1.6919 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  84/141 [================>.............] - ETA: 39s - loss: 1.6914 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  86/141 [=================>............] - ETA: 38s - loss: 1.6907 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  88/141 [=================>............] - ETA: 37s - loss: 1.6911 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  90/141 [==================>...........] - ETA: 35s - loss: 1.6910 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  92/141 [==================>...........] - ETA: 34s - loss: 1.6911 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  94/141 [===================>..........] - ETA: 32s - loss: 1.6906 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  96/141 [===================>..........] - ETA: 31s - loss: 1.6907 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
#  98/141 [===================>..........] - ETA: 30s - loss: 1.6907 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 100/141 [====================>.........] - ETA: 28s - loss: 1.6901 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 102/141 [====================>.........] - ETA: 27s - loss: 1.6893 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 104/141 [=====================>........] - ETA: 25s - loss: 1.6894 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 106/141 [=====================>........] - ETA: 24s - loss: 1.6892 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 108/141 [=====================>........] - ETA: 23s - loss: 1.6885 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 110/141 [======================>.......] - ETA: 21s - loss: 1.6871 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 112/141 [======================>.......] - ETA: 20s - loss: 1.6862 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 114/141 [=======================>......] - ETA: 18s - loss: 1.6850 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 116/141 [=======================>......] - ETA: 17s - loss: 1.6847 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 118/141 [========================>.....] - ETA: 16s - loss: 1.6836 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 120/141 [========================>.....] - ETA: 14s - loss: 1.6833 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 122/141 [========================>.....] - ETA: 13s - loss: 1.6828 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 124/141 [=========================>....] - ETA: 11s - loss: 1.6819 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 126/141 [=========================>....] - ETA: 10s - loss: 1.6810 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 128/141 [==========================>...] - ETA: 9s - loss: 1.6807 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 130/141 [==========================>...] - ETA: 7s - loss: 1.6801 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 132/141 [===========================>..] - ETA: 6s - loss: 1.6795 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 134/141 [===========================>..] - ETA: 4s - loss: 1.6784 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 136/141 [===========================>..] - ETA: 3s - loss: 1.6775 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 138/141 [============================>.] - ETA: 2s - loss: 1.6763 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 140/141 [============================>.] - ETA: 0s - loss: 1.6755 - accuracy: 0.0667
# Epoch 00002: accuracy did not improve from 0.06667
# 141/141 [==============================] - 101s 717ms/step - loss: 1.6751 - accuracy: 0.0667 - val_loss: 1.7453 - val_accuracy: 0.0667
# Epoch 3/200
#   1/141 [..............................] - ETA: 0s - loss: 1.5784 - accuracy: 0.0667
# Epoch 00003: accuracy did not improve from 0.06667
#   3/141 [..............................] - ETA: 1:03 - loss: 1.5966 - accuracy: 0.0667
# Epoch 00003: accuracy improved from 0.06667 to 0.06680, saving model to weights.best.hdf5
#   5/141 [>.............................] - ETA: 1:21 - loss: 1.6067 - accuracy: 0.0673
# Epoch 00003: accuracy improved from 0.06680 to 0.06771, saving model to weights.best.hdf5
#   7/141 [>.............................] - ETA: 1:31 - loss: 1.6265 - accuracy: 0.0681
# Epoch 00003: accuracy improved from 0.06771 to 0.06816, saving model to weights.best.hdf5
#   9/141 [>.............................] - ETA: 1:32 - loss: 1.6155 - accuracy: 0.0683
# Epoch 00003: accuracy improved from 0.06816 to 0.06875, saving model to weights.best.hdf5
#  11/141 [=>............................] - ETA: 1:34 - loss: 1.6017 - accuracy: 0.0688
# Epoch 00003: accuracy improved from 0.06875 to 0.06901, saving model to weights.best.hdf5
#  13/141 [=>............................] - ETA: 1:34 - loss: 1.5994 - accuracy: 0.0692
# Epoch 00003: accuracy improved from 0.06901 to 0.06935, saving model to weights.best.hdf5
#  15/141 [==>...........................] - ETA: 1:33 - loss: 1.5969 - accuracy: 0.0697
# Epoch 00003: accuracy improved from 0.06935 to 0.06982, saving model to weights.best.hdf5
#  17/141 [==>...........................] - ETA: 1:32 - loss: 1.5975 - accuracy: 0.0700
# Epoch 00003: accuracy improved from 0.06982 to 0.07028, saving model to weights.best.hdf5
#  19/141 [===>..........................] - ETA: 1:31 - loss: 1.5964 - accuracy: 0.0704
# Epoch 00003: accuracy improved from 0.07028 to 0.07052, saving model to weights.best.hdf5
#  21/141 [===>..........................] - ETA: 1:30 - loss: 1.5969 - accuracy: 0.0706
# Epoch 00003: accuracy improved from 0.07052 to 0.07067, saving model to weights.best.hdf5
#  23/141 [===>..........................] - ETA: 1:30 - loss: 1.5982 - accuracy: 0.0708
# Epoch 00003: accuracy improved from 0.07067 to 0.07088, saving model to weights.best.hdf5
#  25/141 [====>.........................] - ETA: 1:29 - loss: 1.5954 - accuracy: 0.0708
# Epoch 00003: accuracy did not improve from 0.07088
#  27/141 [====>.........................] - ETA: 1:27 - loss: 1.5942 - accuracy: 0.0709
# Epoch 00003: accuracy improved from 0.07088 to 0.07106, saving model to weights.best.hdf5
#  29/141 [=====>........................] - ETA: 1:25 - loss: 1.5946 - accuracy: 0.0711
# Epoch 00003: accuracy improved from 0.07106 to 0.07122, saving model to weights.best.hdf5
#  31/141 [=====>........................] - ETA: 1:24 - loss: 1.5907 - accuracy: 0.0714
# Epoch 00003: accuracy improved from 0.07122 to 0.07145, saving model to weights.best.hdf5
#  33/141 [======>.......................] - ETA: 1:23 - loss: 1.5916 - accuracy: 0.0716
# Epoch 00003: accuracy improved from 0.07145 to 0.07178, saving model to weights.best.hdf5
#  35/141 [======>.......................] - ETA: 1:22 - loss: 1.5916 - accuracy: 0.0719
# Epoch 00003: accuracy improved from 0.07178 to 0.07209, saving model to weights.best.hdf5
#  37/141 [======>.......................] - ETA: 1:20 - loss: 1.5907 - accuracy: 0.0721
# Epoch 00003: accuracy improved from 0.07209 to 0.07219, saving model to weights.best.hdf5
#  39/141 [=======>......................] - ETA: 1:19 - loss: 1.5916 - accuracy: 0.0722
# Epoch 00003: accuracy improved from 0.07219 to 0.07234, saving model to weights.best.hdf5
#  41/141 [=======>......................] - ETA: 1:17 - loss: 1.5908 - accuracy: 0.0725
# Epoch 00003: accuracy improved from 0.07234 to 0.07269, saving model to weights.best.hdf5
#  43/141 [========>.....................] - ETA: 1:16 - loss: 1.5894 - accuracy: 0.0730
# Epoch 00003: accuracy improved from 0.07269 to 0.07345, saving model to weights.best.hdf5
#  45/141 [========>.....................] - ETA: 1:14 - loss: 1.5873 - accuracy: 0.0738
# Epoch 00003: accuracy improved from 0.07345 to 0.07418, saving model to weights.best.hdf5
#  47/141 [=========>....................] - ETA: 1:13 - loss: 1.5876 - accuracy: 0.0746
# Epoch 00003: accuracy improved from 0.07418 to 0.07495, saving model to weights.best.hdf5
#  49/141 [=========>....................] - ETA: 1:11 - loss: 1.5849 - accuracy: 0.0752
# Epoch 00003: accuracy improved from 0.07495 to 0.07544, saving model to weights.best.hdf5
#  51/141 [=========>....................] - ETA: 1:10 - loss: 1.5857 - accuracy: 0.0757
# Epoch 00003: accuracy improved from 0.07544 to 0.07612, saving model to weights.best.hdf5
#  53/141 [==========>...................] - ETA: 1:09 - loss: 1.5845 - accuracy: 0.0764
# Epoch 00003: accuracy improved from 0.07612 to 0.07660, saving model to weights.best.hdf5
#  55/141 [==========>...................] - ETA: 1:07 - loss: 1.5835 - accuracy: 0.0769
# Epoch 00003: accuracy improved from 0.07660 to 0.07706, saving model to weights.best.hdf5
#  57/141 [===========>..................] - ETA: 1:05 - loss: 1.5834 - accuracy: 0.0773
# Epoch 00003: accuracy improved from 0.07706 to 0.07758, saving model to weights.best.hdf5
#  59/141 [===========>..................] - ETA: 1:04 - loss: 1.5832 - accuracy: 0.0777
# Epoch 00003: accuracy improved from 0.07758 to 0.07793, saving model to weights.best.hdf5
#  61/141 [===========>..................] - ETA: 1:02 - loss: 1.5848 - accuracy: 0.0781
# Epoch 00003: accuracy improved from 0.07793 to 0.07828, saving model to weights.best.hdf5
#  63/141 [============>.................] - ETA: 1:01 - loss: 1.5846 - accuracy: 0.0784
# Epoch 00003: accuracy improved from 0.07828 to 0.07857, saving model to weights.best.hdf5
#  65/141 [============>.................] - ETA: 59s - loss: 1.5854 - accuracy: 0.0788
# Epoch 00003: accuracy improved from 0.07857 to 0.07884, saving model to weights.best.hdf5
#  67/141 [=============>................] - ETA: 58s - loss: 1.5851 - accuracy: 0.0789
# Epoch 00003: accuracy improved from 0.07884 to 0.07900, saving model to weights.best.hdf5
#  69/141 [=============>................] - ETA: 56s - loss: 1.5831 - accuracy: 0.0792
# Epoch 00003: accuracy improved from 0.07900 to 0.07933, saving model to weights.best.hdf5
#  71/141 [==============>...............] - ETA: 55s - loss: 1.5829 - accuracy: 0.0795
# Epoch 00003: accuracy improved from 0.07933 to 0.07939, saving model to weights.best.hdf5
#  73/141 [==============>...............] - ETA: 53s - loss: 1.5842 - accuracy: 0.0793
# Epoch 00003: accuracy did not improve from 0.07939
#  75/141 [==============>...............] - ETA: 51s - loss: 1.5835 - accuracy: 0.0792
# Epoch 00003: accuracy did not improve from 0.07939
#  77/141 [===============>..............] - ETA: 50s - loss: 1.5822 - accuracy: 0.0791
# Epoch 00003: accuracy did not improve from 0.07939
#  79/141 [===============>..............] - ETA: 48s - loss: 1.5815 - accuracy: 0.0790
# Epoch 00003: accuracy did not improve from 0.07939
#  81/141 [================>.............] - ETA: 46s - loss: 1.5812 - accuracy: 0.0789
# Epoch 00003: accuracy did not improve from 0.07939
#  83/141 [================>.............] - ETA: 45s - loss: 1.5805 - accuracy: 0.0792
# Epoch 00003: accuracy did not improve from 0.07939
#  85/141 [=================>............] - ETA: 43s - loss: 1.5806 - accuracy: 0.0794
# Epoch 00003: accuracy improved from 0.07939 to 0.07958, saving model to weights.best.hdf5
#  87/141 [=================>............] - ETA: 42s - loss: 1.5814 - accuracy: 0.0797
# Epoch 00003: accuracy improved from 0.07958 to 0.07971, saving model to weights.best.hdf5
#  89/141 [=================>............] - ETA: 40s - loss: 1.5808 - accuracy: 0.0798
# Epoch 00003: accuracy improved from 0.07971 to 0.07986, saving model to weights.best.hdf5
#  91/141 [==================>...........] - ETA: 39s - loss: 1.5806 - accuracy: 0.0800
# Epoch 00003: accuracy improved from 0.07986 to 0.08008, saving model to weights.best.hdf5
#  93/141 [==================>...........] - ETA: 37s - loss: 1.5803 - accuracy: 0.0802
# Epoch 00003: accuracy improved from 0.08008 to 0.08037, saving model to weights.best.hdf5
#  95/141 [===================>..........] - ETA: 36s - loss: 1.5797 - accuracy: 0.0804
# Epoch 00003: accuracy improved from 0.08037 to 0.08054, saving model to weights.best.hdf5
#  97/141 [===================>..........] - ETA: 34s - loss: 1.5793 - accuracy: 0.0806
# Epoch 00003: accuracy improved from 0.08054 to 0.08073, saving model to weights.best.hdf5
#  99/141 [====================>.........] - ETA: 32s - loss: 1.5775 - accuracy: 0.0808
# Epoch 00003: accuracy improved from 0.08073 to 0.08093, saving model to weights.best.hdf5
# 101/141 [====================>.........] - ETA: 31s - loss: 1.5774 - accuracy: 0.0810
# Epoch 00003: accuracy improved from 0.08093 to 0.08115, saving model to weights.best.hdf5
# 103/141 [====================>.........] - ETA: 29s - loss: 1.5774 - accuracy: 0.0812
# Epoch 00003: accuracy improved from 0.08115 to 0.08134, saving model to weights.best.hdf5
# 105/141 [=====================>........] - ETA: 28s - loss: 1.5763 - accuracy: 0.0814
# Epoch 00003: accuracy improved from 0.08134 to 0.08148, saving model to weights.best.hdf5
# 107/141 [=====================>........] - ETA: 26s - loss: 1.5749 - accuracy: 0.0816
# Epoch 00003: accuracy improved from 0.08148 to 0.08163, saving model to weights.best.hdf5
# 109/141 [======================>.......] - ETA: 25s - loss: 1.5749 - accuracy: 0.0817
# Epoch 00003: accuracy improved from 0.08163 to 0.08179, saving model to weights.best.hdf5
# 111/141 [======================>.......] - ETA: 23s - loss: 1.5744 - accuracy: 0.0819
# Epoch 00003: accuracy improved from 0.08179 to 0.08192, saving model to weights.best.hdf5
# 113/141 [=======================>......] - ETA: 22s - loss: 1.5738 - accuracy: 0.0820
# Epoch 00003: accuracy improved from 0.08192 to 0.08204, saving model to weights.best.hdf5
# 115/141 [=======================>......] - ETA: 20s - loss: 1.5734 - accuracy: 0.0821
# Epoch 00003: accuracy improved from 0.08204 to 0.08216, saving model to weights.best.hdf5
# 117/141 [=======================>......] - ETA: 18s - loss: 1.5732 - accuracy: 0.0822
# Epoch 00003: accuracy improved from 0.08216 to 0.08225, saving model to weights.best.hdf5
# 119/141 [========================>.....] - ETA: 17s - loss: 1.5724 - accuracy: 0.0824
# Epoch 00003: accuracy improved from 0.08225 to 0.08243, saving model to weights.best.hdf5
# 121/141 [========================>.....] - ETA: 15s - loss: 1.5721 - accuracy: 0.0825
# Epoch 00003: accuracy improved from 0.08243 to 0.08255, saving model to weights.best.hdf5
# 123/141 [=========================>....] - ETA: 14s - loss: 1.5720 - accuracy: 0.0826
# Epoch 00003: accuracy improved from 0.08255 to 0.08258, saving model to weights.best.hdf5
# 125/141 [=========================>....] - ETA: 12s - loss: 1.5715 - accuracy: 0.0826
# Epoch 00003: accuracy improved from 0.08258 to 0.08265, saving model to weights.best.hdf5
# 127/141 [==========================>...] - ETA: 11s - loss: 1.5706 - accuracy: 0.0827
# Epoch 00003: accuracy improved from 0.08265 to 0.08281, saving model to weights.best.hdf5
# 129/141 [==========================>...] - ETA: 9s - loss: 1.5704 - accuracy: 0.0829
# Epoch 00003: accuracy improved from 0.08281 to 0.08294, saving model to weights.best.hdf5
# 131/141 [==========================>...] - ETA: 7s - loss: 1.5698 - accuracy: 0.0830
# Epoch 00003: accuracy improved from 0.08294 to 0.08303, saving model to weights.best.hdf5
# 133/141 [===========================>..] - ETA: 6s - loss: 1.5699 - accuracy: 0.0831
# Epoch 00003: accuracy improved from 0.08303 to 0.08311, saving model to weights.best.hdf5
# 135/141 [===========================>..] - ETA: 4s - loss: 1.5691 - accuracy: 0.0832
# Epoch 00003: accuracy improved from 0.08311 to 0.08321, saving model to weights.best.hdf5
# 137/141 [============================>.] - ETA: 3s - loss: 1.5687 - accuracy: 0.0832
# Epoch 00003: accuracy improved from 0.08321 to 0.08326, saving model to weights.best.hdf5
# 139/141 [============================>.] - ETA: 1s - loss: 1.5687 - accuracy: 0.0833
# Epoch 00003: accuracy improved from 0.08326 to 0.08338, saving model to weights.best.hdf5
# 141/141 [==============================] - 115s 813ms/step - loss: 1.5689 - accuracy: 0.0834 - val_loss: 1.6728 - val_accuracy: 0.0827
# Epoch 4/200
#
# Epoch 00004: accuracy improved from 0.08338 to 0.09219, saving model to weights.best.hdf5
#   2/141 [..............................] - ETA: 45s - loss: 1.4795 - accuracy: 0.0893
# Epoch 00004: accuracy did not improve from 0.09219
#   4/141 [..............................] - ETA: 1:12 - loss: 1.4790 - accuracy: 0.0923
# Epoch 00004: accuracy did not improve from 0.09219
#   6/141 [>.............................] - ETA: 1:19 - loss: 1.4870 - accuracy: 0.0904
# Epoch 00004: accuracy did not improve from 0.09219
#   8/141 [>.............................] - ETA: 1:22 - loss: 1.5039 - accuracy: 0.0907
# Epoch 00004: accuracy did not improve from 0.09219
#  10/141 [=>............................] - ETA: 1:23 - loss: 1.5086 - accuracy: 0.0911
# Epoch 00004: accuracy did not improve from 0.09219
#  12/141 [=>............................] - ETA: 1:24 - loss: 1.5084 - accuracy: 0.0917
# Epoch 00004: accuracy did not improve from 0.09219
#  14/141 [=>............................] - ETA: 1:23 - loss: 1.5042 - accuracy: 0.0917
# Epoch 00004: accuracy did not improve from 0.09219
#  16/141 [==>...........................] - ETA: 1:22 - loss: 1.5012 - accuracy: 0.0917
# Epoch 00004: accuracy did not improve from 0.09219
#  18/141 [==>...........................] - ETA: 1:21 - loss: 1.5044 - accuracy: 0.0915
# Epoch 00004: accuracy did not improve from 0.09219
#  20/141 [===>..........................] - ETA: 1:21 - loss: 1.5075 - accuracy: 0.0917
# Epoch 00004: accuracy did not improve from 0.09219
#  22/141 [===>..........................] - ETA: 1:20 - loss: 1.5054 - accuracy: 0.0915
# Epoch 00004: accuracy did not improve from 0.09219
#  24/141 [====>.........................] - ETA: 1:18 - loss: 1.5029 - accuracy: 0.0915
# Epoch 00004: accuracy did not improve from 0.09219
#  26/141 [====>.........................] - ETA: 1:17 - loss: 1.5054 - accuracy: 0.0913
# Epoch 00004: accuracy did not improve from 0.09219
#  28/141 [====>.........................] - ETA: 1:16 - loss: 1.5023 - accuracy: 0.0914
# Epoch 00004: accuracy did not improve from 0.09219
#  30/141 [=====>........................] - ETA: 1:15 - loss: 1.5042 - accuracy: 0.0914
# Epoch 00004: accuracy did not improve from 0.09219
#  32/141 [=====>........................] - ETA: 1:14 - loss: 1.5034 - accuracy: 0.0913
# Epoch 00004: accuracy did not improve from 0.09219
#  34/141 [======>.......................] - ETA: 1:13 - loss: 1.5029 - accuracy: 0.0912
# Epoch 00004: accuracy did not improve from 0.09219
#  36/141 [======>.......................] - ETA: 1:11 - loss: 1.5029 - accuracy: 0.0914
# Epoch 00004: accuracy did not improve from 0.09219
#  38/141 [=======>......................] - ETA: 1:10 - loss: 1.5039 - accuracy: 0.0912
# Epoch 00004: accuracy did not improve from 0.09219
#  40/141 [=======>......................] - ETA: 1:09 - loss: 1.5040 - accuracy: 0.0912
# Epoch 00004: accuracy did not improve from 0.09219
#  42/141 [=======>......................] - ETA: 1:08 - loss: 1.5049 - accuracy: 0.0913
# Epoch 00004: accuracy did not improve from 0.09219
#  44/141 [========>.....................] - ETA: 1:07 - loss: 1.5077 - accuracy: 0.0912
# Epoch 00004: accuracy did not improve from 0.09219
#  46/141 [========>.....................] - ETA: 1:06 - loss: 1.5067 - accuracy: 0.0912
# Epoch 00004: accuracy did not improve from 0.09219
#  48/141 [=========>....................] - ETA: 1:04 - loss: 1.5073 - accuracy: 0.0914
# Epoch 00004: accuracy did not improve from 0.09219
#  50/141 [=========>....................] - ETA: 1:03 - loss: 1.5085 - accuracy: 0.0914
# Epoch 00004: accuracy did not improve from 0.09219
#  52/141 [==========>...................] - ETA: 1:01 - loss: 1.5084 - accuracy: 0.0914
# Epoch 00004: accuracy did not improve from 0.09219
#  54/141 [==========>...................] - ETA: 1:00 - loss: 1.5072 - accuracy: 0.0914
# Epoch 00004: accuracy did not improve from 0.09219
#  56/141 [==========>...................] - ETA: 59s - loss: 1.5076 - accuracy: 0.0914
# Epoch 00004: accuracy did not improve from 0.09219
#  58/141 [===========>..................] - ETA: 57s - loss: 1.5079 - accuracy: 0.0915
# Epoch 00004: accuracy did not improve from 0.09219
#  60/141 [===========>..................] - ETA: 56s - loss: 1.5080 - accuracy: 0.0916
# Epoch 00004: accuracy did not improve from 0.09219
#  62/141 [============>.................] - ETA: 55s - loss: 1.5080 - accuracy: 0.0916
# Epoch 00004: accuracy did not improve from 0.09219
#  64/141 [============>.................] - ETA: 53s - loss: 1.5090 - accuracy: 0.0917
# Epoch 00004: accuracy did not improve from 0.09219
#  66/141 [=============>................] - ETA: 52s - loss: 1.5093 - accuracy: 0.0917
# Epoch 00004: accuracy did not improve from 0.09219
#  68/141 [=============>................] - ETA: 50s - loss: 1.5101 - accuracy: 0.0916
# Epoch 00004: accuracy did not improve from 0.09219
#  70/141 [=============>................] - ETA: 49s - loss: 1.5097 - accuracy: 0.0917
# Epoch 00004: accuracy did not improve from 0.09219
#  72/141 [==============>...............] - ETA: 48s - loss: 1.5099 - accuracy: 0.0917
# Epoch 00004: accuracy did not improve from 0.09219
#  74/141 [==============>...............] - ETA: 47s - loss: 1.5091 - accuracy: 0.0917
# Epoch 00004: accuracy did not improve from 0.09219
#  76/141 [===============>..............] - ETA: 45s - loss: 1.5086 - accuracy: 0.0917
# Epoch 00004: accuracy did not improve from 0.09219
#  78/141 [===============>..............] - ETA: 44s - loss: 1.5091 - accuracy: 0.0916
# Epoch 00004: accuracy did not improve from 0.09219
#  80/141 [================>.............] - ETA: 42s - loss: 1.5082 - accuracy: 0.0916
# Epoch 00004: accuracy did not improve from 0.09219
#  82/141 [================>.............] - ETA: 41s - loss: 1.5073 - accuracy: 0.0918
# Epoch 00004: accuracy did not improve from 0.09219
#  84/141 [================>.............] - ETA: 40s - loss: 1.5065 - accuracy: 0.0919
# Epoch 00004: accuracy did not improve from 0.09219
#  86/141 [=================>............] - ETA: 38s - loss: 1.5065 - accuracy: 0.0919
# Epoch 00004: accuracy did not improve from 0.09219
#  88/141 [=================>............] - ETA: 37s - loss: 1.5061 - accuracy: 0.0919
# Epoch 00004: accuracy did not improve from 0.09219
#  90/141 [==================>...........] - ETA: 36s - loss: 1.5059 - accuracy: 0.0920
# Epoch 00004: accuracy did not improve from 0.09219
#  92/141 [==================>...........] - ETA: 34s - loss: 1.5057 - accuracy: 0.0919
# Epoch 00004: accuracy did not improve from 0.09219
#  94/141 [===================>..........] - ETA: 33s - loss: 1.5047 - accuracy: 0.0921
# Epoch 00004: accuracy did not improve from 0.09219
#  96/141 [===================>..........] - ETA: 31s - loss: 1.5050 - accuracy: 0.0921
# Epoch 00004: accuracy did not improve from 0.09219
#  98/141 [===================>..........] - ETA: 30s - loss: 1.5052 - accuracy: 0.0921
# Epoch 00004: accuracy did not improve from 0.09219
# 100/141 [====================>.........] - ETA: 29s - loss: 1.5049 - accuracy: 0.0921
# Epoch 00004: accuracy did not improve from 0.09219
# 102/141 [====================>.........] - ETA: 27s - loss: 1.5053 - accuracy: 0.0922
# Epoch 00004: accuracy improved from 0.09219 to 0.09219, saving model to weights.best.hdf5
# 104/141 [=====================>........] - ETA: 26s - loss: 1.5060 - accuracy: 0.0923
# Epoch 00004: accuracy improved from 0.09219 to 0.09229, saving model to weights.best.hdf5
# 106/141 [=====================>........] - ETA: 24s - loss: 1.5064 - accuracy: 0.0923
# Epoch 00004: accuracy improved from 0.09229 to 0.09233, saving model to weights.best.hdf5
# 108/141 [=====================>........] - ETA: 23s - loss: 1.5060 - accuracy: 0.0924
# Epoch 00004: accuracy improved from 0.09233 to 0.09235, saving model to weights.best.hdf5
# 110/141 [======================>.......] - ETA: 22s - loss: 1.5051 - accuracy: 0.0924
# Epoch 00004: accuracy improved from 0.09235 to 0.09240, saving model to weights.best.hdf5
# 112/141 [======================>.......] - ETA: 20s - loss: 1.5040 - accuracy: 0.0924
# Epoch 00004: accuracy improved from 0.09240 to 0.09245, saving model to weights.best.hdf5
# 114/141 [=======================>......] - ETA: 19s - loss: 1.5037 - accuracy: 0.0925
# Epoch 00004: accuracy did not improve from 0.09245
# 116/141 [=======================>......] - ETA: 18s - loss: 1.5034 - accuracy: 0.0925
# Epoch 00004: accuracy improved from 0.09245 to 0.09252, saving model to weights.best.hdf5
# 118/141 [========================>.....] - ETA: 16s - loss: 1.5029 - accuracy: 0.0925
# Epoch 00004: accuracy did not improve from 0.09252
# 120/141 [========================>.....] - ETA: 15s - loss: 1.5024 - accuracy: 0.0926
# Epoch 00004: accuracy improved from 0.09252 to 0.09257, saving model to weights.best.hdf5
# 122/141 [========================>.....] - ETA: 13s - loss: 1.5024 - accuracy: 0.0926
# Epoch 00004: accuracy improved from 0.09257 to 0.09263, saving model to weights.best.hdf5
# 124/141 [=========================>....] - ETA: 12s - loss: 1.5018 - accuracy: 0.0926
# Epoch 00004: accuracy did not improve from 0.09263
# 126/141 [=========================>....] - ETA: 10s - loss: 1.5011 - accuracy: 0.0926
# Epoch 00004: accuracy improved from 0.09263 to 0.09265, saving model to weights.best.hdf5
# 128/141 [==========================>...] - ETA: 9s - loss: 1.5016 - accuracy: 0.0927
# Epoch 00004: accuracy improved from 0.09265 to 0.09270, saving model to weights.best.hdf5
# 130/141 [==========================>...] - ETA: 8s - loss: 1.5015 - accuracy: 0.0927
# Epoch 00004: accuracy did not improve from 0.09270
# 132/141 [===========================>..] - ETA: 6s - loss: 1.5013 - accuracy: 0.0927
# Epoch 00004: accuracy did not improve from 0.09270
# 134/141 [===========================>..] - ETA: 5s - loss: 1.5008 - accuracy: 0.0927
# Epoch 00004: accuracy did not improve from 0.09270
# 136/141 [===========================>..] - ETA: 3s - loss: 1.5006 - accuracy: 0.0927
# Epoch 00004: accuracy improved from 0.09270 to 0.09270, saving model to weights.best.hdf5
# 138/141 [============================>.] - ETA: 2s - loss: 1.5007 - accuracy: 0.0927
# Epoch 00004: accuracy improved from 0.09270 to 0.09273, saving model to weights.best.hdf5
# 140/141 [============================>.] - ETA: 0s - loss: 1.5005 - accuracy: 0.0927
# Epoch 00004: accuracy did not improve from 0.09273
# 141/141 [==============================] - 106s 749ms/step - loss: 1.5008 - accuracy: 0.0927 - val_loss: 1.6358 - val_accuracy: 0.0877
# Epoch 5/200
#   1/141 [..............................] - ETA: 0s - loss: 1.4621 - accuracy: 0.0943
# Epoch 00005: accuracy improved from 0.09273 to 0.09349, saving model to weights.best.hdf5
#   3/141 [..............................] - ETA: 1:16 - loss: 1.4984 - accuracy: 0.0932
# Epoch 00005: accuracy improved from 0.09349 to 0.09375, saving model to weights.best.hdf5
#   5/141 [>.............................] - ETA: 1:28 - loss: 1.4869 - accuracy: 0.0948
# Epoch 00005: accuracy improved from 0.09375 to 0.09549, saving model to weights.best.hdf5
#   7/141 [>.............................] - ETA: 1:33 - loss: 1.4801 - accuracy: 0.0948
# Epoch 00005: accuracy did not improve from 0.09549
#   9/141 [>.............................] - ETA: 1:31 - loss: 1.4656 - accuracy: 0.0948
# Epoch 00005: accuracy improved from 0.09549 to 0.09557, saving model to weights.best.hdf5
#  11/141 [=>............................] - ETA: 1:32 - loss: 1.4575 - accuracy: 0.0962
# Epoch 00005: accuracy improved from 0.09557 to 0.09575, saving model to weights.best.hdf5
#  13/141 [=>............................] - ETA: 1:33 - loss: 1.4526 - accuracy: 0.0955
# Epoch 00005: accuracy did not improve from 0.09575
#  15/141 [==>...........................] - ETA: 1:31 - loss: 1.4515 - accuracy: 0.0954
# Epoch 00005: accuracy did not improve from 0.09575
#  17/141 [==>...........................] - ETA: 1:29 - loss: 1.4547 - accuracy: 0.0950
# Epoch 00005: accuracy did not improve from 0.09575
#  19/141 [===>..........................] - ETA: 1:27 - loss: 1.4592 - accuracy: 0.0947
# Epoch 00005: accuracy did not improve from 0.09575
#  21/141 [===>..........................] - ETA: 1:26 - loss: 1.4613 - accuracy: 0.0943
# Epoch 00005: accuracy did not improve from 0.09575
#  23/141 [===>..........................] - ETA: 1:24 - loss: 1.4705 - accuracy: 0.0940
# Epoch 00005: accuracy did not improve from 0.09575
#  25/141 [====>.........................] - ETA: 1:22 - loss: 1.4706 - accuracy: 0.0939
# Epoch 00005: accuracy did not improve from 0.09575
#  27/141 [====>.........................] - ETA: 1:21 - loss: 1.4696 - accuracy: 0.0941
# Epoch 00005: accuracy did not improve from 0.09575
#  29/141 [=====>........................] - ETA: 1:19 - loss: 1.4707 - accuracy: 0.0941
# Epoch 00005: accuracy did not improve from 0.09575
#  31/141 [=====>........................] - ETA: 1:18 - loss: 1.4711 - accuracy: 0.0941
# Epoch 00005: accuracy did not improve from 0.09575
#  33/141 [======>.......................] - ETA: 1:17 - loss: 1.4686 - accuracy: 0.0939
# Epoch 00005: accuracy did not improve from 0.09575
#  35/141 [======>.......................] - ETA: 1:15 - loss: 1.4673 - accuracy: 0.0940
# Epoch 00005: accuracy did not improve from 0.09575
#  37/141 [======>.......................] - ETA: 1:14 - loss: 1.4686 - accuracy: 0.0939
# Epoch 00005: accuracy did not improve from 0.09575
#  39/141 [=======>......................] - ETA: 1:12 - loss: 1.4704 - accuracy: 0.0940
# Epoch 00005: accuracy did not improve from 0.09575
#  41/141 [=======>......................] - ETA: 1:11 - loss: 1.4689 - accuracy: 0.0941
# Epoch 00005: accuracy did not improve from 0.09575
# ...
#  53/141 [==========>...................] - ETA: 1:00 - loss: 0.0417 - accuracy: 0.2926
# Epoch 00199: accuracy did not improve from 0.30990
#  55/141 [==========>...................] - ETA: 59s - loss: 0.0416 - accuracy: 0.2926
# Epoch 00199: accuracy did not improve from 0.30990
#  57/141 [===========>..................] - ETA: 57s - loss: 0.0418 - accuracy: 0.2928
# Epoch 00199: accuracy did not improve from 0.30990
#  59/141 [===========>..................] - ETA: 56s - loss: 0.0419 - accuracy: 0.2926
# Epoch 00199: accuracy did not improve from 0.30990
#  61/141 [===========>..................] - ETA: 55s - loss: 0.0421 - accuracy: 0.2923
# Epoch 00199: accuracy did not improve from 0.30990
#  63/141 [============>.................] - ETA: 53s - loss: 0.0422 - accuracy: 0.2921
# Epoch 00199: accuracy did not improve from 0.30990
#  65/141 [============>.................] - ETA: 52s - loss: 0.0424 - accuracy: 0.2924
# Epoch 00199: accuracy did not improve from 0.30990
#  67/141 [=============>................] - ETA: 51s - loss: 0.0422 - accuracy: 0.2925
# Epoch 00199: accuracy did not improve from 0.30990
#  69/141 [=============>................] - ETA: 50s - loss: 0.0422 - accuracy: 0.2926
# Epoch 00199: accuracy did not improve from 0.30990
#  71/141 [==============>...............] - ETA: 48s - loss: 0.0425 - accuracy: 0.2924
# Epoch 00199: accuracy did not improve from 0.30990
#  73/141 [==============>...............] - ETA: 47s - loss: 0.0426 - accuracy: 0.2925
# Epoch 00199: accuracy did not improve from 0.30990
#  75/141 [==============>...............] - ETA: 46s - loss: 0.0426 - accuracy: 0.2924
# Epoch 00199: accuracy did not improve from 0.30990
#  77/141 [===============>..............] - ETA: 44s - loss: 0.0427 - accuracy: 0.2924
# Epoch 00199: accuracy did not improve from 0.30990
#  79/141 [===============>..............] - ETA: 43s - loss: 0.0428 - accuracy: 0.2925
# Epoch 00199: accuracy did not improve from 0.30990
#  81/141 [================>.............] - ETA: 42s - loss: 0.0428 - accuracy: 0.2924
# Epoch 00199: accuracy did not improve from 0.30990
#  83/141 [================>.............] - ETA: 40s - loss: 0.0429 - accuracy: 0.2923
# Epoch 00199: accuracy did not improve from 0.30990
#  85/141 [=================>............] - ETA: 39s - loss: 0.0430 - accuracy: 0.2921
# Epoch 00199: accuracy did not improve from 0.30990
#  87/141 [=================>............] - ETA: 37s - loss: 0.0429 - accuracy: 0.2922
# Epoch 00199: accuracy did not improve from 0.30990
#  89/141 [=================>............] - ETA: 36s - loss: 0.0431 - accuracy: 0.2921
# Epoch 00199: accuracy did not improve from 0.30990
#  91/141 [==================>...........] - ETA: 34s - loss: 0.0432 - accuracy: 0.2920
# Epoch 00199: accuracy did not improve from 0.30990
#  93/141 [==================>...........] - ETA: 33s - loss: 0.0433 - accuracy: 0.2920
# Epoch 00199: accuracy did not improve from 0.30990
#  95/141 [===================>..........] - ETA: 32s - loss: 0.0434 - accuracy: 0.2919
# Epoch 00199: accuracy did not improve from 0.30990
#  97/141 [===================>..........] - ETA: 30s - loss: 0.0436 - accuracy: 0.2917
# Epoch 00199: accuracy did not improve from 0.30990
#  99/141 [====================>.........] - ETA: 29s - loss: 0.0435 - accuracy: 0.2917
# Epoch 00199: accuracy did not improve from 0.30990
# 101/141 [====================>.........] - ETA: 28s - loss: 0.0436 - accuracy: 0.2917
# Epoch 00199: accuracy did not improve from 0.30990
# 103/141 [====================>.........] - ETA: 26s - loss: 0.0437 - accuracy: 0.2917
# Epoch 00199: accuracy did not improve from 0.30990
# 105/141 [=====================>........] - ETA: 25s - loss: 0.0436 - accuracy: 0.2918
# Epoch 00199: accuracy did not improve from 0.30990
# 107/141 [=====================>........] - ETA: 23s - loss: 0.0437 - accuracy: 0.2917
# Epoch 00199: accuracy did not improve from 0.30990
# 109/141 [======================>.......] - ETA: 22s - loss: 0.0437 - accuracy: 0.2916
# Epoch 00199: accuracy did not improve from 0.30990
# 111/141 [======================>.......] - ETA: 21s - loss: 0.0437 - accuracy: 0.2916
# Epoch 00199: accuracy did not improve from 0.30990
# 113/141 [=======================>......] - ETA: 19s - loss: 0.0437 - accuracy: 0.2915
# Epoch 00199: accuracy did not improve from 0.30990
# 115/141 [=======================>......] - ETA: 18s - loss: 0.0438 - accuracy: 0.2915
# Epoch 00199: accuracy did not improve from 0.30990
# 117/141 [=======================>......] - ETA: 16s - loss: 0.0439 - accuracy: 0.2915
# Epoch 00199: accuracy did not improve from 0.30990
# 119/141 [========================>.....] - ETA: 15s - loss: 0.0440 - accuracy: 0.2914
# Epoch 00199: accuracy did not improve from 0.30990
# 121/141 [========================>.....] - ETA: 14s - loss: 0.0440 - accuracy: 0.2914
# Epoch 00199: accuracy did not improve from 0.30990
# 123/141 [=========================>....] - ETA: 12s - loss: 0.0440 - accuracy: 0.2914
# Epoch 00199: accuracy did not improve from 0.30990
# 125/141 [=========================>....] - ETA: 11s - loss: 0.0440 - accuracy: 0.2913
# Epoch 00199: accuracy did not improve from 0.30990
# 127/141 [==========================>...] - ETA: 9s - loss: 0.0440 - accuracy: 0.2913
# Epoch 00199: accuracy did not improve from 0.30990
# 129/141 [==========================>...] - ETA: 8s - loss: 0.0441 - accuracy: 0.2912
# Epoch 00199: accuracy did not improve from 0.30990
# 131/141 [==========================>...] - ETA: 7s - loss: 0.0442 - accuracy: 0.2911
# Epoch 00199: accuracy did not improve from 0.30990
# 133/141 [===========================>..] - ETA: 5s - loss: 0.0442 - accuracy: 0.2910
# Epoch 00199: accuracy did not improve from 0.30990
# 135/141 [===========================>..] - ETA: 4s - loss: 0.0443 - accuracy: 0.2910
# Epoch 00199: accuracy did not improve from 0.30990
# 137/141 [============================>.] - ETA: 2s - loss: 0.0442 - accuracy: 0.2910
# Epoch 00199: accuracy did not improve from 0.30990
# 139/141 [============================>.] - ETA: 1s - loss: 0.0443 - accuracy: 0.2910
# Epoch 00199: accuracy did not improve from 0.30990
# 141/141 [==============================] - 103s 728ms/step - loss: 0.0444 - accuracy: 0.2909 - val_loss: 1.4980 - val_accuracy: 0.1744
# Epoch 200/200
#
# Epoch 00200: accuracy did not improve from 0.30990
#   2/141 [..............................] - ETA: 48s - loss: 0.0410 - accuracy: 0.2974
# Epoch 00200: accuracy did not improve from 0.30990
#   4/141 [..............................] - ETA: 1:12 - loss: 0.0415 - accuracy: 0.2930
# Epoch 00200: accuracy did not improve from 0.30990
#   6/141 [>.............................] - ETA: 1:19 - loss: 0.0417 - accuracy: 0.2969
# Epoch 00200: accuracy did not improve from 0.30990
#   8/141 [>.............................] - ETA: 1:20 - loss: 0.0414 - accuracy: 0.2956
# Epoch 00200: accuracy did not improve from 0.30990
#  10/141 [=>............................] - ETA: 1:20 - loss: 0.0407 - accuracy: 0.2956
# Epoch 00200: accuracy did not improve from 0.30990
#  12/141 [=>............................] - ETA: 1:21 - loss: 0.0412 - accuracy: 0.2950
# Epoch 00200: accuracy did not improve from 0.30990
#  14/141 [=>............................] - ETA: 1:21 - loss: 0.0413 - accuracy: 0.2946
# Epoch 00200: accuracy did not improve from 0.30990
#  16/141 [==>...........................] - ETA: 1:21 - loss: 0.0406 - accuracy: 0.2950
# Epoch 00200: accuracy did not improve from 0.30990
#  18/141 [==>...........................] - ETA: 1:20 - loss: 0.0403 - accuracy: 0.2953
# Epoch 00200: accuracy did not improve from 0.30990
#  20/141 [===>..........................] - ETA: 1:20 - loss: 0.0404 - accuracy: 0.2962
# Epoch 00200: accuracy did not improve from 0.30990
#  22/141 [===>..........................] - ETA: 1:19 - loss: 0.0401 - accuracy: 0.2962
# Epoch 00200: accuracy did not improve from 0.30990
#  24/141 [====>.........................] - ETA: 1:18 - loss: 0.0405 - accuracy: 0.2957
# Epoch 00200: accuracy did not improve from 0.30990
#  26/141 [====>.........................] - ETA: 1:17 - loss: 0.0407 - accuracy: 0.2961
# Epoch 00200: accuracy did not improve from 0.30990
#  28/141 [====>.........................] - ETA: 1:16 - loss: 0.0407 - accuracy: 0.2955
# Epoch 00200: accuracy did not improve from 0.30990
#  30/141 [=====>........................] - ETA: 1:14 - loss: 0.0406 - accuracy: 0.2956
# Epoch 00200: accuracy did not improve from 0.30990
#  32/141 [=====>........................] - ETA: 1:13 - loss: 0.0403 - accuracy: 0.2957
# Epoch 00200: accuracy did not improve from 0.30990
#  34/141 [======>.......................] - ETA: 1:12 - loss: 0.0406 - accuracy: 0.2955
# Epoch 00200: accuracy did not improve from 0.30990
#  36/141 [======>.......................] - ETA: 1:11 - loss: 0.0406 - accuracy: 0.2953
# Epoch 00200: accuracy did not improve from 0.30990
#  38/141 [=======>......................] - ETA: 1:10 - loss: 0.0406 - accuracy: 0.2953
# Epoch 00200: accuracy did not improve from 0.30990
#  40/141 [=======>......................] - ETA: 1:08 - loss: 0.0405 - accuracy: 0.2952
# Epoch 00200: accuracy did not improve from 0.30990
#  42/141 [=======>......................] - ETA: 1:07 - loss: 0.0404 - accuracy: 0.2953
# Epoch 00200: accuracy did not improve from 0.30990
#  44/141 [========>.....................] - ETA: 1:06 - loss: 0.0405 - accuracy: 0.2946
# Epoch 00200: accuracy did not improve from 0.30990
#  46/141 [========>.....................] - ETA: 1:04 - loss: 0.0406 - accuracy: 0.2943
# Epoch 00200: accuracy did not improve from 0.30990
#  48/141 [=========>....................] - ETA: 1:03 - loss: 0.0405 - accuracy: 0.2945
# Epoch 00200: accuracy did not improve from 0.30990
#  50/141 [=========>....................] - ETA: 1:02 - loss: 0.0406 - accuracy: 0.2944
# Epoch 00200: accuracy did not improve from 0.30990
#  52/141 [==========>...................] - ETA: 1:01 - loss: 0.0408 - accuracy: 0.2941
# Epoch 00200: accuracy did not improve from 0.30990
#  54/141 [==========>...................] - ETA: 59s - loss: 0.0407 - accuracy: 0.2942
# Epoch 00200: accuracy did not improve from 0.30990
#  56/141 [==========>...................] - ETA: 58s - loss: 0.0407 - accuracy: 0.2941
# Epoch 00200: accuracy did not improve from 0.30990
#  58/141 [===========>..................] - ETA: 57s - loss: 0.0407 - accuracy: 0.2940
# Epoch 00200: accuracy did not improve from 0.30990
#  60/141 [===========>..................] - ETA: 56s - loss: 0.0407 - accuracy: 0.2940
# Epoch 00200: accuracy did not improve from 0.30990
#  62/141 [============>.................] - ETA: 54s - loss: 0.0408 - accuracy: 0.2940
# Epoch 00200: accuracy did not improve from 0.30990
#  64/141 [============>.................] - ETA: 53s - loss: 0.0407 - accuracy: 0.2939
# Epoch 00200: accuracy did not improve from 0.30990
#  66/141 [=============>................] - ETA: 51s - loss: 0.0408 - accuracy: 0.2936
# Epoch 00200: accuracy did not improve from 0.30990
#  68/141 [=============>................] - ETA: 50s - loss: 0.0409 - accuracy: 0.2933
# Epoch 00200: accuracy did not improve from 0.30990
#  70/141 [=============>................] - ETA: 49s - loss: 0.0409 - accuracy: 0.2932
# Epoch 00200: accuracy did not improve from 0.30990
#  72/141 [==============>...............] - ETA: 47s - loss: 0.0409 - accuracy: 0.2930
# Epoch 00200: accuracy did not improve from 0.30990
#  74/141 [==============>...............] - ETA: 46s - loss: 0.0410 - accuracy: 0.2931
# Epoch 00200: accuracy did not improve from 0.30990
#  76/141 [===============>..............] - ETA: 45s - loss: 0.0410 - accuracy: 0.2930
# Epoch 00200: accuracy did not improve from 0.30990
#  78/141 [===============>..............] - ETA: 43s - loss: 0.0411 - accuracy: 0.2928
# Epoch 00200: accuracy did not improve from 0.30990
#  80/141 [================>.............] - ETA: 42s - loss: 0.0412 - accuracy: 0.2929
# Epoch 00200: accuracy did not improve from 0.30990
#  82/141 [================>.............] - ETA: 41s - loss: 0.0411 - accuracy: 0.2929
# Epoch 00200: accuracy did not improve from 0.30990
#  84/141 [================>.............] - ETA: 39s - loss: 0.0412 - accuracy: 0.2927
# Epoch 00200: accuracy did not improve from 0.30990
#  86/141 [=================>............] - ETA: 38s - loss: 0.0413 - accuracy: 0.2927
# Epoch 00200: accuracy did not improve from 0.30990
#  88/141 [=================>............] - ETA: 36s - loss: 0.0415 - accuracy: 0.2924
# Epoch 00200: accuracy did not improve from 0.30990
#  90/141 [==================>...........] - ETA: 35s - loss: 0.0417 - accuracy: 0.2922
# Epoch 00200: accuracy did not improve from 0.30990
#  92/141 [==================>...........] - ETA: 34s - loss: 0.0417 - accuracy: 0.2923
# Epoch 00200: accuracy did not improve from 0.30990
#  94/141 [===================>..........] - ETA: 32s - loss: 0.0419 - accuracy: 0.2922
# Epoch 00200: accuracy did not improve from 0.30990
#  96/141 [===================>..........] - ETA: 31s - loss: 0.0419 - accuracy: 0.2921
# Epoch 00200: accuracy did not improve from 0.30990
#  98/141 [===================>..........] - ETA: 30s - loss: 0.0419 - accuracy: 0.2922
# Epoch 00200: accuracy did not improve from 0.30990
# 100/141 [====================>.........] - ETA: 28s - loss: 0.0419 - accuracy: 0.2922
# Epoch 00200: accuracy did not improve from 0.30990
# 102/141 [====================>.........] - ETA: 27s - loss: 0.0420 - accuracy: 0.2922
# Epoch 00200: accuracy did not improve from 0.30990
# 104/141 [=====================>........] - ETA: 25s - loss: 0.0420 - accuracy: 0.2922
# Epoch 00200: accuracy did not improve from 0.30990
# 106/141 [=====================>........] - ETA: 24s - loss: 0.0421 - accuracy: 0.2921
# Epoch 00200: accuracy did not improve from 0.30990
# 108/141 [=====================>........] - ETA: 23s - loss: 0.0422 - accuracy: 0.2920
# Epoch 00200: accuracy did not improve from 0.30990
# 110/141 [======================>.......] - ETA: 21s - loss: 0.0422 - accuracy: 0.2920
# Epoch 00200: accuracy did not improve from 0.30990
# 112/141 [======================>.......] - ETA: 20s - loss: 0.0422 - accuracy: 0.2919
# Epoch 00200: accuracy did not improve from 0.30990
# 114/141 [=======================>......] - ETA: 18s - loss: 0.0423 - accuracy: 0.2919
# Epoch 00200: accuracy did not improve from 0.30990
# 116/141 [=======================>......] - ETA: 17s - loss: 0.0423 - accuracy: 0.2916
# Epoch 00200: accuracy did not improve from 0.30990
# 118/141 [========================>.....] - ETA: 16s - loss: 0.0424 - accuracy: 0.2916
# Epoch 00200: accuracy did not improve from 0.30990
# 120/141 [========================>.....] - ETA: 14s - loss: 0.0424 - accuracy: 0.2916
# Epoch 00200: accuracy did not improve from 0.30990
# 122/141 [========================>.....] - ETA: 13s - loss: 0.0425 - accuracy: 0.2917
# Epoch 00200: accuracy did not improve from 0.30990
# 124/141 [=========================>....] - ETA: 11s - loss: 0.0426 - accuracy: 0.2917
# Epoch 00200: accuracy did not improve from 0.30990
# 126/141 [=========================>....] - ETA: 10s - loss: 0.0427 - accuracy: 0.2915
# Epoch 00200: accuracy did not improve from 0.30990
# 128/141 [==========================>...] - ETA: 9s - loss: 0.0427 - accuracy: 0.2915
# Epoch 00200: accuracy did not improve from 0.30990
# 130/141 [==========================>...] - ETA: 7s - loss: 0.0428 - accuracy: 0.2914
# Epoch 00200: accuracy did not improve from 0.30990
# 132/141 [===========================>..] - ETA: 6s - loss: 0.0429 - accuracy: 0.2913
# Epoch 00200: accuracy did not improve from 0.30990
# 134/141 [===========================>..] - ETA: 4s - loss: 0.0429 - accuracy: 0.2913
# Epoch 00200: accuracy did not improve from 0.30990
# 136/141 [===========================>..] - ETA: 3s - loss: 0.0430 - accuracy: 0.2912
# Epoch 00200: accuracy did not improve from 0.30990
# 138/141 [============================>.] - ETA: 2s - loss: 0.0430 - accuracy: 0.2912
# Epoch 00200: accuracy did not improve from 0.30990
# 140/141 [============================>.] - ETA: 0s - loss: 0.0431 - accuracy: 0.2911
# Epoch 00200: accuracy did not improve from 0.30990
# 141/141 [==============================] - 101s 719ms/step - loss: 0.0431 - accuracy: 0.2911 - val_loss: 1.4940 - val_accuracy: 0.1744

# %%
import pandas as pd
from matplotlib import pyplot as plt
loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(loss, label='train Loss')
plt.plot(val_loss, label='valid Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid()
plt.show()

plt.plot(acc, label='train Acc')
plt.plot(val_acc, label='valid Acc')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
from keras.models import load_model

# model = load_model('weights.best.hdf5')
model.load_weights('weights.best.hdf5')


encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(rnn_size,))
decoder_state_input_c = Input(shape=(rnn_size,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs_inf, state_h_inf, state_c_inf = decoder_lstm(decoder_after_embedding,
                                                            initial_state=decoder_states_inputs)
decoder_states_inf = [state_h_inf, state_c_inf]
decoder_outputs_inf = decoder_dense(decoder_outputs_inf)

# %%
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs_inf] + decoder_states_inf
)

# %%
# 采样
def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = outputToken_idx['BEGIN_']
    stop = False
    decoded_sentence = ''
    while not stop:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)
        sampled_token_idx = np.argmax(output_tokens)
        sampled_word = idx_outputToken[sampled_token_idx]
        decoded_sentence += ' ' + sampled_word

        if sampled_word == '_END' or len(decoded_sentence) > 60:
            stop = True
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_idx
        # Update states
        states_value = [h, c]

    return decoded_sentence

# 简单测试 采样
text_to_translate = 'Are you happy ?'
encoder_input_to_translate = np.zeros(
    (1, max_input_seq_len),
    dtype=np.float32)
for t, word in enumerate(text_to_translate.split()):
    encoder_input_to_translate[0, t] = inputToken_idx[word]

print(decode_sequence(encoder_input_to_translate))
# Out:
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000219EB55E798> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  Bist du für mich? _END
